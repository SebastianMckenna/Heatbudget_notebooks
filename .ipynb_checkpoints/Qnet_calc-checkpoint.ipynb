# %%
import xarray as xr
import dask
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import scipy
import os
import glob as glob
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import calendar

# %%
ls /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/*.nc
# Out:
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_185001-185012.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_185101-185112.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_185201-185212.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_185301-185312.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_185401-185412.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_185501-185512.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_185601-185612.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_185701-185712.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_185801-185812.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_185901-185912.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_186001-186012.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_186101-186112.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_186201-186212.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_186301-186312.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_186401-186412.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_186501-186512.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_186601-186612.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_186701-186712.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_186801-186812.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_186901-186912.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_187001-187012.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_187101-187112.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_187201-187212.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_187301-187312.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_187401-187412.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_187501-187512.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_187601-187612.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_187701-187712.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_187801-187812.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_187901-187912.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_188001-188012.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_188101-188112.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_188201-188212.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_188301-188312.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_188401-188412.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_188501-188512.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_188601-188612.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_188701-188712.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_188801-188812.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_188901-188912.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_189001-189012.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_189101-189112.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_189201-189212.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_189301-189312.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_189401-189412.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_189501-189512.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_189601-189612.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_189701-189712.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_189801-189812.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_189901-189912.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_190001-190012.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_190101-190112.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_190201-190212.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_190301-190312.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_190401-190412.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_190501-190512.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_190601-190612.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_190701-190712.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_190801-190812.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_190901-190912.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_191001-191012.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_191101-191112.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_191201-191212.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_191301-191312.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_191401-191412.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_191501-191512.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_191601-191612.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_191701-191712.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_191801-191812.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_191901-191912.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_192001-192012.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_192101-192112.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_192201-192212.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_192301-192312.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_192401-192412.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_192501-192512.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_192601-192612.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_192701-192712.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_192801-192812.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_192901-192912.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_193001-193012.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_193101-193112.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_193201-193212.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_193301-193312.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_193401-193412.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_193501-193512.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_193601-193612.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_193701-193712.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_193801-193812.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_193901-193912.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_194001-194012.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_194101-194112.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_194201-194212.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_194301-194312.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_194401-194412.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_194501-194512.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_194601-194612.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_194701-194712.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_194801-194812.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_194901-194912.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_195001-195012.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_195101-195112.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_195201-195212.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_195301-195312.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_195401-195412.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_195501-195512.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_195601-195612.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_195701-195712.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_195801-195812.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_195901-195912.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_196001-196012.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_196101-196112.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_196201-196212.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_196301-196312.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_196401-196412.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_196501-196512.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_196601-196612.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_196701-196712.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_196801-196812.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_196901-196912.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_197001-197012.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_197101-197112.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_197201-197212.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_197301-197312.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_197401-197412.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_197501-197512.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_197601-197612.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_197701-197712.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_197801-197812.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_197901-197912.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_198001-198012.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_198101-198112.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_198201-198212.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_198301-198312.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_198401-198412.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_198501-198512.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_198601-198612.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_198701-198712.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_198801-198812.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_198901-198912.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_199001-199012.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_199101-199112.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_199201-199212.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_199301-199312.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_199401-199412.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_199501-199512.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_199601-199612.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_199701-199712.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_199801-199812.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_199901-199912.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_200001-200012.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_200101-200112.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_200201-200212.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_200301-200312.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_200401-200412.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_200501-200512.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_200601-200612.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_200701-200712.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_200801-200812.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_200901-200912.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_201001-201012.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_201101-201112.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_201201-201212.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_201301-201312.nc.nc
# /home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/rsntds_Omon_EC-Earth3_historical_r11i1p1f1_gn_201401-201412.nc.nc

# %%
#load in Q data (Model only)
SW = xr.open_mfdataset('/home/z5113258/Documents/data/CMIP6/EC-Earth3/RSNTDS/*.nc').rsntds
Q = xr.open_dataset('/home/z5113258/Documents/data/CMIP6/EC-Earth3/EC-Earth3_HFDS.nc').hfds

# %%
qpen = (SW*((0.67*np.exp(-50))+((1-0.67)*np.exp(-50/17))))

# %%
qpen.groupby("time.month").mean("time").plot(col = 'month', col_wrap= 4)
# Out:
# /home/z5113258/anaconda3/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)

# %%
Qn = (Q-SW*((0.67*np.exp(-50))+((1-0.67)*np.exp(-50/17))))/(3986*1026*50)

# %%
np.exp(2)
# Out:
# 7.38905609893065

# %%
#load in godas sw or what i think it is to see if it very different
GSW = xr.open_dataset('/g/data/e14/sm2435/GODAS/dswrf_remap.nc').dswrf
GQ = xr.open_mfdataset('/g/data/e14/sm2435/GODAS/remapcon_1/thflx/*.nc').thflx
# Out:
# /apps/jupyterlab/2.1.4-py3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   This is separate from the ipykernel package so we can avoid doing imports until
# /apps/xarray/0.15.1-py3.7/lib/python3.7/site-packages/xarray-0.15.1-py3.7.egg/xarray/backends/api.py:941: FutureWarning: The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,

# %%
GQ
# Out:
# <xarray.DataArray 'thflx' (time: 492, lat: 180, lon: 360)>
# dask.array<concatenate, shape=(492, 180, 360), dtype=float32, chunksize=(12, 180, 360), chunktype=numpy.ndarray>
# Coordinates:
#   * lon      (lon) float64 -179.5 -178.5 -177.5 -176.5 ... 177.5 178.5 179.5
#   * lat      (lat) float64 -89.5 -88.5 -87.5 -86.5 -85.5 ... 86.5 87.5 88.5 89.5
#   * time     (time) datetime64[ns] 1980-01-01 1980-02-01 ... 2020-12-01
# Attributes:
#     long_name:                Total downward heat flux at surface (downward i...
#     units:                    W/m2
#     dataset:                  NCEP GODAS
#     var_desc:                 total downward heat flux at surface
#     level_desc:               surface
#     statistic:                Monthly Mean
#     parent_stat:              Individual Obs
#     sub_center:               Environmental Modeling Center
#     center:                   US National Weather Service - NCEP (WMC)
#     level_indicator:          1
#     gds_grid_type:            0
#     parameter_table_version:  129
#     parameter_number:         202
#     actual_range:             [-1010.12604   673.7022 ]

# %%
def date_to_middle(vari, varname):
    data_list = []
    
    try:
        for i in range(len(vari.time)):
            val = ((vari[i,:,:]+vari[i+1,:,:])/2).values
            data_list.append(val)
    except:
        print('error')
    arr = np.asarray(data_list)
    test = xr.DataArray(arr, coords={'time': vari.time[1:], 'lat': vari.lat, 'lon':vari.lon},
                 dims=['time', 'lat', 'lon'], attrs=dict(
            description=varname))
    return test

# %%
GQ1 = date_to_middle(GQ, 'Q')
GSW1= date_to_middle(GSW, 'SW')
# Out:
# error
# error

# %%
GQ1c=GQ1.groupby('time.month').mean('time')
# Out:
# /apps/xarray/0.15.1-py3.7/lib/python3.7/site-packages/xarray-0.15.1-py3.7.egg/xarray/core/nanops.py:142: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis=axis, dtype=dtype)

# %%
GQ2c=GQ2.groupby('time.month').mean('time')
GQc= GQ.groupby('time.month').mean('time')
# Out:
# /apps/xarray/0.15.1-py3.7/lib/python3.7/site-packages/xarray-0.15.1-py3.7.egg/xarray/core/nanops.py:142: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis=axis, dtype=dtype)

# %%
SW=SW.groupby('time.month').mean('time')
Q=Q.groupby('time.month').mean('time')
# Out:
# /apps/xarray/0.15.1-py3.7/lib/python3.7/site-packages/xarray-0.15.1-py3.7.egg/xarray/core/nanops.py:142: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis=axis, dtype=dtype)

# %%
(Q-GQ2c)[9].plot(vmin = -100, vmax = 100, cmap = 'RdBu_r')#-1

# %%
(Q-GQc)[9].plot(vmin = -100, vmax = 100, cmap = 'RdBu_r')#+1
# Out:
# /apps/dask/2.19.0-py3.7/lib/python3.7/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)

# %%
(Q-GQc)[6].plot(vmin = -100, vmax = 100, cmap = 'RdBu_r')
# Out:
# /apps/dask/2.19.0-py3.7/lib/python3.7/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)

# %%
(GQ2c-GQ1c)[6].plot()

# %%
def plot_background_sml(ax, i, j):
    #for use with plotting 12 months. need to change 
    ax.set_extent([30., 120., -25., 15.])
    ax.add_feature(cfeature.COASTLINE.with_scale('50m'), linewidth=0.5)
    ax.add_feature(cfeature.LAND)
    gl = ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False)
    gl.top_labels = False
    gl.right_labels = False
    if i == 5:
        gl.bottom_labels = True
    else:
        gl.bottom_labels = False
    if j > 0:
        gl.left_labels = False
    return ax

def plot_sml(dict_name, maxv, minv, varname):
    fig, axes = plt.subplots(nrows=6, ncols=2, figsize=(10, 12), sharey='all', sharex='all', 
                             subplot_kw={'projection':ccrs.PlateCarree()})
    var = dict_name
    lons = var.sel(lat=slice(-55,40),lon=slice(30,150)).lon
    lats = var.sel(lat=slice(-55,40),lon=slice(30,150)).lat
    #dTdt
    #axes[0,num].set_title(key)
    axi=1
    for col in range(0,2):
        for row in range(0,6):

            axes[row, col].pcolormesh(lons, lats, var.sel(lat=slice(-55,40),lon=slice(30,150)).sel(month = (axi)), 
                                #levels = 41, 
                                cmap = 'RdBu_r', 
                                #add_colorbar=True, 
                                vmin = minv, vmax = maxv, 
                                transform=ccrs.PlateCarree())
            #title is month
            axes[row, col].set_title(var.sel(month = (axi)).month.values)
            plot_background_sml(axes[row, col], row, col)
            axi=axi+1

            
    cbar_ax2 = fig.add_axes([1, 0.5, 0.03, 0.3])
    cmap2 = plt.cm.RdBu_r
    bounds = np.linspace(minv, maxv, 21)
    norm2 = mpl.colors.BoundaryNorm(bounds, cmap2.N)
    cb = mpl.colorbar.ColorbarBase(cbar_ax2, cmap=cmap2, norm=norm2,
        spacing='proportional', ticks=bounds, boundaries=bounds)
    fig.suptitle(varname)
    #fig.tight_layout()
    return fig

# %%
X=plot_sml((Q-GQc), 100, -100, 'model -godas')
X.savefig('/g/data/e14/sm2435/figures/model-godas.png', dpi = 300, bbox_inches='tight')
# Out:
# /apps/dask/2.19.0-py3.7/lib/python3.7/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /apps/dask/2.19.0-py3.7/lib/python3.7/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /apps/dask/2.19.0-py3.7/lib/python3.7/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /apps/dask/2.19.0-py3.7/lib/python3.7/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /apps/dask/2.19.0-py3.7/lib/python3.7/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /apps/dask/2.19.0-py3.7/lib/python3.7/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /apps/dask/2.19.0-py3.7/lib/python3.7/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /apps/dask/2.19.0-py3.7/lib/python3.7/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /apps/dask/2.19.0-py3.7/lib/python3.7/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /apps/dask/2.19.0-py3.7/lib/python3.7/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /apps/dask/2.19.0-py3.7/lib/python3.7/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /apps/dask/2.19.0-py3.7/lib/python3.7/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)

# %%
X=plot_sml((Q-GQ1c), 100, -100, "model -godas[1:]")
X.savefig('/g/data/e14/sm2435/figures/model-godas1.png', dpi = 300, bbox_inches='tight')

# %%
X=plot_sml((Q-GQ2c), 100, -100, "model -godas[:-1]")
X.savefig('/g/data/e14/sm2435/figures/model-godas-1.png', dpi = 300, bbox_inches='tight')

# %%
(SW-(GSW2.groupby('time.month').mean('time')))[0].plot(vmin = -100, vmax = 100, cmap = 'RdBu_r')
# Out:
# /apps/dask/2.19.0-py3.7/lib/python3.7/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)

# %%
(SW-(GSW.groupby('time.month').mean('time')))[0].plot(vmin = -100, vmax = 100, cmap = 'RdBu_r')
# Out:
# /apps/dask/2.19.0-py3.7/lib/python3.7/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)

# %%
(SW-(GSW1.groupby('time.month').mean('time')))[0].plot(vmin = -100, vmax = 100, cmap = 'RdBu_r')
# Out:
# /apps/dask/2.19.0-py3.7/lib/python3.7/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)

# %%
SW[0].plot(vmin = 0, vmax = 350)
# Out:
# /apps/dask/2.19.0-py3.7/lib/python3.7/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)

# %%
(GSW2.groupby('time.month').mean('time'))[0].plot(vmin = 0, vmax = 350)
